# %% [markdown]
# # p1. 读取和处理candidates.csv和annotations.csv

# %%
import numpy as np
import copy
import pandas as pd
import functools
import glob
import os
import csv

from collections import namedtuple, defaultdict

# %%
path = "D:/Code/data/luna16/"

# %%
df = pd.read_csv(path + "candidates.csv")

# %%
df.head()
# Out:
#                                            seriesuid  coordX  coordY  coordZ  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -56.08  -67.85 -311.92
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   53.21 -244.41 -245.17
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.66 -121.80 -286.62
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -33.66  -72.75 -308.41
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -32.25  -85.36 -362.51
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df.shape
# Out:
# (551065, 5)

# %% [markdown]
# > https://luna16.grand-challenge.org/Data/
#
# 官网上写了candidates.csv与candidates_V2.csv的区别。
# 视频中使用的是candidates.csv

# %%
df_v2 = pd.read_csv(path + "candidates_V2.csv")
df_v2.head(5), df_v2.shape
# Out:
# (                                           seriesuid     coordX      coordY  \
#  0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  68.420000  -74.480000
#  1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -95.209361  -91.809406
#  2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -24.766755 -120.379294
#  3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -63.080000  -65.740000
#  4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  52.946688  -92.688873
#
#         coordZ  class
#  0 -288.700000      0
#  1 -377.426350      0
#  2 -273.361539      0
#  3 -344.240000      0
#  4 -241.067872      0  ,
#  (754975, 5))

# %% [markdown]
# 官网上表示：
# - 1120/1186 个结节
# - **It has to be noted that there can be multiple candidates per nodule.**
# 可能意思是，这些候选位置可能有重叠，然后有些class为1的存在重复的结节。

# %%
df.iloc[:, -1].value_counts()
# Out:
# class
# 0    549714
# 1      1351
# Name: count, dtype: int64

# %%
df_v2.iloc[:, -1].value_counts()
# Out:
# class
# 0    753418
# 1      1557
# Name: count, dtype: int64

# %%
annotations = pd.read_csv(path + "annotations.csv")
annotations.head()
# Out:
#                                            seriesuid      coordX      coordY  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017 -140.944586
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824  192.102405
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547  172.464881
#
#        coordZ  diameter_mm
# 0 -298.387506     5.651471
# 1 -227.121250     4.224708
# 2  876.374496     5.786348
# 3 -391.081276     8.143262
# 4 -405.493732    18.545150

# %%
annotations.shape
# Out:
# (1186, 5)

# %% [markdown]
# 当使用 pandas 读取数据时,如果数据源没有提供明确的列名,pandas 会自动为这些列生成默认的列名,通常格式为 "Unnamed: 0"、"Unnamed: 1" 等。
# 使用 column.startswith("Unnamed") 可以方便地识别和筛选出这些自动生成的列名,以便进行后续的数据清理和处理。

# %%
columns = [column for column in annotations.columns if not column.startswith("Unnamed")]
columns, len(columns)
# Out:
# (['seriesuid', 'coordX', 'coordY', 'coordZ', 'diameter_mm'], 5)

# %% [markdown]
# 这里额外获取了文件系统中的真正存在的数据文件，因为此处我们为了简化代码，只在data目录里解压了subset0和subset1的数据，后续处理就只需处理这两个子集，以防因数据集不全而出bug

# %%
mhd_list = glob.glob(path + "subset*/*.mhd")

# %%
len(mhd_list), mhd_list[0]
# Out:
# (178,
#  'D:/Code/data/luna16\\subset0\\1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821

#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.616033753016904899083676284739',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.621916089407825046337959219998',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.640729228179368154416184318668',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.655242448149322898770987310561',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.657775098760536289051744981056',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.663019255629770796363333877035',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.674809958213117379592437424616',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.690929968028676628605553365896',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.716498695101447665580610403574',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.724251104254976962355686318345',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.752756872840730509471096155114',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.756684168227383088294595834066',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.768276876111112560631432843476',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.801945620899034889998809817499',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.802595762867498341201607992711',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.805925269324902055566754756843',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.826812708000318290301835871780',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.832260670372728970918746541371',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.861997885565255340442123234170',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.888291896309937415860209787179',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.892375496445736188832556446335',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.898642529028521482602829374444',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.910607280658963002048724648683',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.935683764293840351008008793409',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.952265563663939823135367733681',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.970264865033574190975654369557',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.975254950136384517744116790879',
#   '1.3.6.1.4.1.14519.5.2.1.6279.6001.979083010707182900091062408058'})

# %%
with open(path + "annotations.csv", "r") as f:
    reader = csv.reader(f)
    columns = next(reader)
    line_n = 0
    for row in reader:
        line_n += 1
    print(line_n)
# Out:
# 1186

# %%
"""
diameter_dict = {}
with open(path + "annotations.csv", "r") as f:
    reader = csv.reader(f)
    columns = next(reader)
    for row in reader:
        # row是一个list
        series_uid = row[0]
        annotation_center_xyz = tuple([float(x) for x in row[1:4]])
        annotation_diameter_mm = float(row[4])
        # 通过使用setdefault()方法，可以确保每个series_uid都有一个对应的列表，即使在遍历annotations.csv文件时遇到多个具有相同series_uid的行也不会覆盖先前的值。
        diameter_dict.setdefault(series_uid, []).append(
            (annotation_center_xyz, annotation_diameter_mm)
        )
"""
# Out:
# '\ndiameter_dict = {}\nwith open(path + "annotations.csv", "r") as f:\n    reader = csv.reader(f)\n    columns = next(reader)\n    for row in reader:\n        # row是一个list\n        series_uid = row[0]\n        annotation_center_xyz = tuple([float(x) for x in row[1:4]])\n        annotation_diameter_mm = float(row[4])\n        # 通过使用setdefault()方法，可以确保每个series_uid都有一个对应的列表，即使在遍历annotations.csv文件时遇到多个具有相同series_uid的行也不会覆盖先前的值。\n        diameter_dict.setdefault(series_uid, []).append(\n            (annotation_center_xyz, annotation_diameter_mm)\n        )\n'

# %%
# 使用defaultdict来代替上面的setdefault()方法
diameter_dict = defaultdict(list)
with open(path + "annotations.csv", "r") as f:
    reader = csv.reader(f)
    columns = next(reader)
    for row in reader:
        series_uid = row[0]
        annotation_center_xyz = tuple([float(x) for x in row[1:4]])
        annotation_diameter_mm = float(row[4])
        diameter_dict[series_uid].append(
            (annotation_center_xyz, annotation_diameter_mm)
        )

# %%
annotations_df = pd.read_csv(path + "annotations.csv")
annotations_df.shape, annotations_df.head()
# Out:
# ((1186, 5),
#                                             seriesuid      coordX      coordY  \
#  0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
#  1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
#  2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017 -140.944586
#  3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824  192.102405
#  4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547  172.464881
#
#         coordZ  diameter_mm
#  0 -298.387506     5.651471
#  1 -227.121250     4.224708
#  2  876.374496     5.786348
#  3 -391.081276     8.143262
#  4 -405.493732    18.545150  )

# %%
for idx, row in annotations_df.iterrows():
    print(row.tolist())
    if idx > 3:
        break
# Out:
# ['1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860', -128.6994211, -175.3192718, -298.3875064, 5.651470635]
# ['1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860', 103.7836509, -211.9251487, -227.12125, 4.224708481]
# ['1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208', 69.63901724, -140.9445859, 876.3744957, 5.786347814]
# ['1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', -24.0138242, 192.1024053, -391.0812764, 8.143261683]
# ['1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', 2.441546798, 172.4648812, -405.4937318, 18.54514997]

# %%
first_line = np.array(annotations_df.iloc[0])
first_line
# Out:
# array(['1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860',
#        -128.6994211, -175.3192718, -298.3875064, 5.651470635],
#       dtype=object)

# %%
diameter_dict["1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860"]
# Out:
# [((-128.6994211, -175.3192718, -298.3875064), 5.651470635),
#  ((103.7836509, -211.9251487, -227.12125), 4.224708481)]

# %%
len(diameter_dict)
# Out:
# 601

# %%
require_on_disk_bool = True
CandidateInfoTuple = namedtuple(
    "CandidateInfoTuple", ["is_nodule_bool", "diameter_mm", "series_uid", "center_xyz"]
)

# %%
candidate_info_list = []
with open(path + "candidates.csv", "r") as f:
    reader = csv.reader(f)
    columns = next(reader)
    for row in reader:
        series_uid = row[0]

        if series_uid not in present_on_disk_set and require_on_disk_bool:
            continue

        is_nodule_bool = bool(int(row[4]))
        candidate_center_xyz = tuple([float(x) for x in row[1:4]])

        candidate_diameter_mm = 0.0
        # 因为上面使用了defaultdict，所以这里不需要判断series_uid是否在diameter_dict中
        # 这里对比了候选结节的中心点和直径与annotations.csv中的中心点和直径，如果候选结节的中心点和直径在annotations.csv中的中心点和直径的1/4范围内，则认为是同一个结节
        # 就可以得到候选结节的直径
        # 至于不在1/4范围内的候选结节，直径就是0.0
        for annotation_tuple in diameter_dict[series_uid]:
            annotation_center_xyz, annotation_diameter_mm = annotation_tuple
            for i in range(3):
                delta_mm = abs(candidate_center_xyz[i] - annotation_center_xyz[i])
                if delta_mm > annotation_diameter_mm / 4:
                    break
            else:
                candidate_diameter_mm = annotation_diameter_mm
                break

        candidate_info_list.append(
            CandidateInfoTuple(
                is_nodule_bool, candidate_diameter_mm, series_uid, candidate_center_xyz
            )
        )

# %%
candidate_info_list[:5]
# Out:
# [CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-25.40019966, -199.1034346, -114.4721508)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-42.31, -162.9, -170.18)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-72.42, -209.82, -206.73)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-35.31, -125.79, -145.59)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-57.72, -113.88, -123.8))]

# %%
len(candidate_info_list)
# Out:
# 110143

# %%
candidate_info_list
# Out:
# [CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-25.40019966, -199.1034346, -114.4721508)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-42.31, -162.9, -170.18)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-72.42, -209.82, -206.73)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-35.31, -125.79, -145.59)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-57.72, -113.88, -123.8)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-97.63, -204.22, -262.94)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-91.33, -124.38, -266.46)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-86.43, -129.99, -260.84)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-28.7763795959, -140.996208616, -188.270399324)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-82.3010894751, -122.52122058, -146.106614282)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-48.34361031, -137.916443, -228.6137035)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(68.501066955, -210.10264565, -263.17473655)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(38.21, -152.4, -156.83)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-46.51, -93.57, -149.1)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(34.02866897, -150.3159558, -184.0883069)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(28.89190159, -169.465506625, -168.647809525)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-47.91, -127.19, -199.7)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-64.02, -177.61, -196.18)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(65.52, -148.19, -196.18)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-48.61, -165.0, -116.77)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-71.02, -126.49, -217.97)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-40.91, -225.23, -201.81)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(-20.6, -148.19, -107.64)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866', center_xyz=(
),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-76.0997562694, 141.620769117, -470.883998782)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-37.6110307493, 195.357168046, -378.671661594)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-59.08, 220.38, -399.85)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(62.24, 137.62, -392.83)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(46.11, 193.73, -352.13)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-94.85, 225.99, -474.23)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(56.63, 226.69, -472.13)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(82.57, 202.15, -390.02)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-75.21, 228.8, -543.71)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-31.03, 176.9, -538.8)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-155.411276764, 140.519127453, -505.571276801)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(76.2884480719, 186.589413577, -409.119827801)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(95.4238886809, 163.744777581, -416.894444658)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(58.0470841326, 191.510387207, -395.084223001)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-141.223548594, 78.6496578511, -513.513226008)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-55.5763907439, 132.281496833, -384.041124473)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-120.535769445, 187.343538245, -429.126923297)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(100.709999774, 202.754704713, -528.706557594)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-87.6553335349, 156.538333129, -445.550000215)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-110.626638159, 157.958810128, -427.715086451)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(57.6599997914, 163.691999781, -403.482143073)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-63.8247330503, 163.23264862, -456.42137423)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-76.5020002127, 204.712333131, -437.397333544)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-92.2233335525, 159.675333135, -444.829166894)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-137.316717771, 162.423106661, -457.232697407)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-51.6406252188, 192.891374784, -413.091875219)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-49.6457872421, 179.064916472, -429.462963189)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-99.4386240448, 127.171128211, -474.070183728)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-79.7210347002, 170.470103233, -457.13137953)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-111.331989166, 64.8063500721, -500.348526915)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-96.8475565535, 190.864802617, -478.160246677)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-98.6733977431, 134.303631723, -481.991744564)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-55.3606039015, 166.964768813, -409.484383423)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-75.8727370893, 206.956999795, -374.099894964)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-67.3694761958, 74.1994958488, -487.436899756)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(77.3574997897, 161.084499777, -459.517500215)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-133.855116493, 182.132503665, -463.009302541)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-89.0925864197, 153.689413589, -420.464655385)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-113.79, 200.74, -459.5)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-124.01641532, 81.6494752549, -488.104717198)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(52.42, 162.87, -394.23)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-59.08, 108.87, -404.06)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-113.79, 104.66, -470.02)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-95.55, 176.9, -419.5)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-41.55, 119.39, -413.18)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-71.0, 225.29, -448.97)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(89.69398616, 215.3271096, -505.6906367)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-71.09118489, 211.2587607, -473.6066531)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-64.76216364, 175.5500302, -416.56828745)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(72.0913212138, 190.106208547, -427.437171795)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(-44.40416199, 172.1755568, -425.8120983)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(49.52673232, 223.4615721, -389.7751444)),
#  CandidateInfoTuple(is_nodule_bool=False, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217', center_xyz=(71.66460592, 173.2973049, -447.7262358)),
#  ...]

# %% [markdown]
# ## p2. 读取和处理CT文件

# %%
import SimpleITK as sitk

# %%
series_uid = "1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866"
mhd_path = glob.glob(path + f"subset*/{series_uid}.mhd")[0]
ct_mhd = sitk.ReadImage(mhd_path)
ct_arr = np.array(sitk.GetArrayFromImage(ct_mhd), dtype=np.float32)

# %%
ct_arr, ct_arr.shape
# Out:
# (array([[[ -990., -1007., -1016., ...,  -988.,  -973.,  -966.],
#          [ -985., -1001., -1014., ...,  -978.,  -960.,  -961.],
#          [ -994., -1013., -1017., ...,  -972.,  -956.,  -969.],
#          ...,
#          [ -941.,  -953.,  -959., ...,  -918.,  -917.,  -943.],
#          [ -960.,  -981.,  -979., ...,  -929.,  -903.,  -926.],
#          [ -978.,  -980.,  -965., ...,  -953.,  -925.,  -924.]],
#
#         [[ -996., -1019., -1019., ...,  -998.,  -997.,  -994.],
#          [ -989., -1005., -1011., ...,  -991.,  -991.,  -988.],
#          [ -987.,  -996.,  -996., ...,  -989.,  -993.,  -991.],
#          ...,
#          [ -974.,  -972.,  -953., ...,  -946.,  -949.,  -964.],
#          [ -974.,  -984.,  -965., ...,  -948.,  -944.,  -963.],
#          [ -989.,  -992.,  -969., ...,  -948.,  -949.,  -971.]],
#
#         [[-1009., -1014., -1008., ..., -1010., -1014., -1011.],
#          [ -997.,  -992.,  -999., ..., -1003., -1005.,  -991.],
#          [ -999.,  -987.,  -981., ...,  -988.,  -994.,  -986.],
#          ...,
#          [ -966.,  -950.,  -915., ...,  -937.,  -939.,  -944.],
#          [ -949.,  -933.,  -922., ...,  -932.,  -934.,  -940.],
#          [ -945.,  -936.,  -943., ...,  -933.,  -924.,  -935.]],
#
#         ...,
#
#         [[ -982.,  -973.,  -979., ...,  -982.,  -982., -1008.],
#          [ -992.,  -978.,  -976., ...,  -984.,  -981., -1004.],
#          [-1003., -1000.,  -989., ...,  -988.,  -995., -1011.],
#          ...,
#          [ -974.,  -963.,  -963., ...,  -930.,  -922.,  -939.],
#          [ -960.,  -953.,  -953., ...,  -950.,  -936.,  -940.],
#          [ -952.,  -956.,  -955., ...,  -950.,  -946.,  -945.]],
#
#         [[-1015., -1001.,  -992., ...,  -972., -1001., -1018.],
#          [-1014.,  -995.,  -984., ...,  -992.,  -987., -1001.],
#          [-1012.,  -996.,  -980., ..., -1018.,  -996.,  -995.],
#          ...,
#          [ -945.,  -929.,  -923., ...,  -920.,  -927.,  -953.],
#          [ -961.,  -954.,  -948., ...,  -923.,  -938.,  -969.],
#          [ -969.,  -968.,  -962., ...,  -913.,  -933.,  -970.]],
#
#         [[ -999.,  -992., -1004., ...,  -996.,  -998., -1008.],
#          [ -992.,  -977.,  -992., ..., -1000.,  -995., -1011.],
#          [ -991.,  -978.,  -992., ..., -1003., -1006., -1016.],
#          ...,
#          [ -945.,  -932.,  -929., ...,  -951.,  -947.,  -948.],
#          [ -956.,  -947.,  -939., ...,  -951.,  -951.,  -951.],
#          [ -971.,  -955.,  -937., ...,  -961.,  -967.,  -961.]]],
#        dtype=float32),
#  (171, 512, 512))

# %%
import sys

sys.path.append("../../src/")

import util.util as ut

# %%
ut.irc2xyz
# Out:
# <function util.util.irc2xyz(coord_irc, origin_xyz, vxSize_xyz, direction_a)>

# %%
ct_arr.clip(-1000, 1000, ct_arr)

hu_arr = ct_arr
IrcTuple = namedtuple("IrcTuple", ["index", "row", "col"])
XyzTuple = namedtuple("XyzTuple", ["x", "y", "z"])

origin_xyz = XyzTuple(*ct_mhd.GetOrigin())
vx_size_xyz = XyzTuple(*ct_mhd.GetSpacing())
direction_arr = np.array(ct_mhd.GetDirection()).reshape(3, 3)

# %%
origin_xyz, vx_size_xyz, direction_arr
# Out:
# (XyzTuple(x=-127.755859375, y=-277.755859375, z=-351.5),
#  XyzTuple(x=0.48828125, y=0.48828125, z=1.7999999523162842),
#  array([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]]))

# %%
def getRawCandidate(center_xyz, width_irc):
    center_irc = ut.xyz2irc(center_xyz, origin_xyz, vx_size_xyz, direction_arr)

    slice_list = []
    for axis, center_val in enumerate(center_irc):
        start_ndx = int(round(center_val - width_irc[axis] / 2))
        end_ndx = int(start_ndx + width_irc[axis])

        assert center_val >= 0 and center_val < hu_arr.shape[axis], repr(
            [series_uid, center_xyz, origin_xyz, vx_size_xyz, center_irc, axis]
        )

        # 处理边界情况
        if start_ndx < 0:
            start_ndx = 0
            end_ndx = int(width_irc[axis])

        if end_ndx > hu_arr.shape[axis]:
            end_ndx = hu_arr.shape[axis]
            start_ndx = int(hu_arr.shape[axis] - width_irc[axis])

        slice_list.append(slice(start_ndx, end_ndx))

    ct_chunk = hu_arr[tuple(slice_list)]
    return ct_chunk, center_irc

# %%
temp = getRawCandidate((-30, -30, -60), (10, 10, 10))
temp
# Out:
# (array([[[-910., -923., -945., -938., -907., -903., -924., -920., -887.,
#           -879.],
#          [-927., -922., -930., -925., -894., -880., -901., -924., -918.,
#           -904.],
#          [-917., -907., -912., -917., -903., -884., -892., -919., -940.,
#           -937.],
#          [-903., -901., -910., -925., -920., -893., -877., -897., -935.,
#           -952.],
#          [-920., -911., -919., -937., -930., -889., -851., -862., -905.,
#           -939.],
#          [-954., -937., -934., -944., -938., -896., -844., -836., -874.,
#           -910.],
#          [-968., -941., -931., -932., -931., -909., -869., -844., -860.,
#           -892.],
#          [-942., -933., -913., -904., -904., -913., -907., -888., -879.,
#           -889.],
#          [-903., -912., -903., -892., -895., -915., -934., -931., -899.,
#           -879.],
#          [-875., -888., -897., -899., -907., -921., -934., -935., -910.,
#           -889.]],
#
#         [[-919., -913., -905., -898., -884., -892., -941., -967., -935.,
#           -903.],
#          [-922., -910., -900., -898., -881., -880., -926., -962., -935.,
#           -896.],
#          [-907., -902., -902., -910., -899., -881., -893., -922., -929.,
#           -917.],
#          [-898., -889., -893., -906., -911., -891., -868., -881., -914.,
#           -930.],
#          [-921., -898., -878., -881., -901., -897., -866., -866., -897.,
#           -917.],
#          [-968., -940., -896., -876., -899., -913., -891., -879., -892.,
#           -896.],
#          [-967., -963., -934., -902., -907., -930., -923., -905., -906.,
#           -901.],
#          [-917., -941., -947., -916., -891., -906., -930., -930., -925.,
#           -920.],
#          [-878., -903., -925., -913., -882., -883., -919., -935., -927.,
#           -909.],
#          [-874., -881., -899., -910., -907., -903., -915., -924., -914.,
#           -896.]],
#
#         [[-872., -874., -877., -894., -909., -930., -950., -947., -911.,
#           -883.],
#          [-872., -890., -900., -908., -912., -920., -940., -956., -925.,
#           -878.],
#          [-888., -895., -905., -917., -925., -915., -916., -932., -920.,
#           -886.],
#          [-913., -905., -900., -907., -919., -920., -908., -909., -917.,
#           -905.],
#          [-946., -932., -901., -886., -904., -923., -914., -905., -910.,
#           -909.],
#          [-954., -946., -914., -891., -904., -921., -917., -911., -914.,
#           -907.],
#          [-926., -924., -913., -899., -900., -908., -904., -915., -933.,
#           -933.],
#          [-891., -893., -896., -887., -883., -889., -892., -909., -944.,
#           -968.],
#          [-866., -865., -881., -887., -896., -907., -907., -912., -937.,
#           -972.],
#          [-849., -838., -865., -904., -934., -947., -943., -932., -930.,
#           -941.]],
#
#         [[-878., -883., -887., -884., -879., -895., -923., -935., -915.,
#           -891.],
#          [-883., -889., -892., -897., -896., -895., -901., -913., -920.,
#           -919.],
#          [-888., -898., -905., -917., -923., -913., -901., -897., -909.,
#           -928.],
#          [-897., -904., -911., -916., -915., -918., -917., -899., -891.,
#           -909.],
#          [-907., -918., -925., -917., -909., -914., -919., -900., -881.,
#           -897.],
#          [-914., -936., -948., -943., -926., -909., -907., -905., -900.,
#           -913.],
#          [-919., -935., -937., -936., -926., -907., -904., -922., -928.,
#           -922.],
#          [-914., -910., -894., -894., -916., -930., -928., -925., -922.,
#           -915.],
#          [-886., -882., -882., -895., -931., -960., -949., -913., -901.,
#           -916.],
#          [-859., -886., -918., -934., -937., -936., -922., -900., -902.,
#           -921.]],
#
#         [[-922., -945., -945., -924., -907., -903., -899., -894., -889.,
#           -868.],
#          [-914., -933., -931., -922., -915., -902., -883., -883., -900.,
#           -895.],
#          [-911., -933., -934., -923., -916., -902., -882., -872., -894.,
#           -910.],
#          [-912., -938., -946., -921., -897., -900., -905., -886., -878.,
#           -904.],
#          [-909., -920., -926., -908., -892., -908., -926., -904., -877.,
#           -894.],
#          [-911., -909., -910., -911., -912., -916., -917., -910., -900.,
#           -901.],
#          [-924., -930., -923., -920., -921., -914., -910., -917., -920.,
#           -909.],
#          [-935., -947., -930., -914., -912., -926., -933., -926., -911.,
#           -903.],
#          [-923., -943., -929., -910., -917., -946., -953., -928., -905.,
#           -908.],
#          [-911., -951., -954., -931., -920., -935., -936., -913., -904.,
#           -918.]],
#
#         [[-878., -898., -912., -916., -916., -910., -902., -898., -890.,
#           -877.],
#          [-894., -902., -904., -912., -919., -906., -894., -900., -923.,
#           -930.],
#          [-903., -899., -896., -904., -906., -905., -911., -925., -941.,
#           -950.],
#          [-899., -891., -891., -893., -900., -917., -940., -947., -942.,
#           -938.],
#          [-888., -875., -879., -906., -933., -948., -954., -939., -923.,
#           -927.],
#          [-888., -873., -888., -937., -967., -959., -932., -911., -906.,
#           -923.],
#          [-921., -912., -908., -932., -943., -930., -914., -909., -916.,
#           -927.],
#          [-964., -944., -904., -890., -898., -918., -932., -937., -937.,
#           -935.],
#          [-960., -938., -889., -857., -877., -921., -948., -953., -945.,
#           -940.],
#          [-933., -937., -900., -863., -870., -907., -935., -947., -943.,
#           -934.]],
#
#         [[-865., -882., -895., -899., -891., -892., -901., -914., -923.,
#           -915.],
#          [-880., -880., -888., -900., -891., -886., -904., -926., -934.,
#           -923.],
#          [-906., -897., -898., -912., -906., -894., -913., -939., -935.,
#           -913.],
#          [-909., -916., -915., -916., -909., -901., -913., -927., -918.,
#           -907.],
#          [-898., -920., -927., -926., -927., -922., -910., -907., -914.,
#           -927.],
#          [-896., -899., -911., -935., -958., -950., -918., -905., -928.,
#           -950.],
#          [-902., -872., -881., -924., -964., -962., -926., -917., -936.,
#           -948.],
#          [-911., -872., -871., -905., -947., -960., -943., -928., -924.,
#           -919.],
#          [-918., -896., -884., -888., -915., -952., -959., -937., -913.,
#           -896.],
#          [-927., -927., -908., -879., -884., -933., -969., -960., -926.,
#           -899.]],
#
#         [[-870., -855., -875., -906., -913., -911., -926., -956., -973.,
#           -953.],
#          [-901., -888., -896., -911., -915., -913., -925., -953., -969.,
#           -949.],
#          [-934., -933., -935., -935., -928., -920., -930., -942., -945.,
#           -930.],
#          [-941., -956., -969., -967., -942., -924., -920., -918., -909.,
#           -905.],
#          [-939., -957., -972., -971., -955., -923., -894., -888., -899.,
#           -916.],
#          [-938., -946., -944., -947., -963., -943., -898., -888., -919.,
#           -950.],
#          [-918., -924., -920., -929., -960., -963., -928., -912., -935.,
#           -958.],
#          [-893., -906., -919., -929., -947., -958., -950., -937., -932.,
#           -943.],
#          [-884., -904., -920., -925., -927., -941., -949., -948., -936.,
#           -936.],
#          [-901., -920., -926., -910., -908., -926., -942., -946., -942.,
#           -939.]],
#
#         [[-912., -897., -882., -899., -937., -954., -959., -970., -963.,
#           -932.],
#          [-907., -917., -906., -911., -948., -972., -969., -968., -964.,
#           -938.],
#          [-915., -941., -926., -914., -947., -979., -975., -959., -950.,
#           -931.],
#          [-920., -954., -951., -943., -957., -972., -960., -949., -944.,
#           -928.],
#          [-949., -979., -982., -965., -953., -945., -927., -925., -934.,
#           -931.],
#          [-985., -995., -981., -953., -932., -922., -911., -903., -920.,
#           -938.],
#          [-999., -983., -961., -943., -925., -917., -915., -907., -923.,
#           -953.],
#          [-975., -952., -942., -944., -927., -903., -903., -918., -935.,
#           -958.],
#          [-930., -920., -918., -930., -923., -897., -889., -907., -925.,
#           -943.],
#          [-902., -906., -910., -928., -942., -928., -907., -900., -905.,
#           -925.]],
#
#         [[-952., -955., -935., -919., -928., -948., -955., -941., -915.,
#           -892.],
#          [-917., -912., -908., -913., -936., -955., -950., -932., -920.,
#           -912.],
#          [-904., -907., -910., -917., -936., -958., -955., -946., -956.,
#           -956.],
#          [-932., -935., -936., -931., -933., -942., -951., -967., -987.,
#           -987.],
#          [-961., -958., -952., -941., -926., -921., -931., -960., -985.,
#           -978.],
#          [-958., -961., -954., -939., -923., -916., -915., -926., -946.,
#           -944.],
#          [-949., -947., -943., -930., -918., -918., -913., -904., -917.,
#           -943.],
#          [-939., -927., -923., -919., -910., -908., -908., -905., -921.,
#           -953.],
#          [-935., -924., -922., -921., -911., -904., -907., -915., -929.,
#           -947.],
#          [-928., -936., -938., -943., -936., -919., -908., -911., -922.,
#           -928.]]], dtype=float32),
#  IrcTuple(index=162, row=507, col=200))

# %%
temp[0].shape, temp[1]
# Out:
# ((10, 10, 10), IrcTuple(index=162, row=507, col=200))
